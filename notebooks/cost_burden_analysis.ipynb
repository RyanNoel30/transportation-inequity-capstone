# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load cleaned data
df = pd.read_csv('../data/cleaned/clean_transportation.csv')
print(df.head())
print(df.info())

# %% [markdown]
# ## Calculate Transportation Cost Burden

# %%
# Transportation cost burden = (annual transport costs / annual income) * 100
    
100
